# %%
# [1] 라이브러리 임포트
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, LayerNormalization, Dropout, GlobalAveragePooling1D
from tensorflow.keras.layers import MultiHeadAttention, Add

# [2] Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')

# [3] 데이터 로딩
csv_path = '/content/drive/MyDrive/Colab Notebooks/data/ngv/datasetIRB2400.csv'
df = pd.read_csv(csv_path)
print("데이터셋 로딩 완료")
print(df.head())

# [4] 입력 및 출력 설정
X = df[['q1_in', 'q2_in', 'q3_in', 'q4_in', 'q5_in', 'q6_in']].values
y = df[['x', 'y', 'z', 'yaw', 'pitch', 'roll']].values

# [5] 정규화
scaler_X = StandardScaler()
scaler_y = StandardScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# [6] 시퀀스 생성
def create_sequences(X, y, time_steps=10):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        Xs.append(X[i:i+time_steps])
        ys.append(y[i+time_steps])
    return np.array(Xs), np.array(ys)

time_steps = 10
X_seq, y_seq = create_sequences(X_scaled, y_scaled, time_steps)

# [7] 학습/테스트 분리
X_train, X_test, y_train, y_test = train_test_split(
    X_seq, y_seq, test_size=0.2, random_state=42)
print(f"Train shape: {X_train.shape}, Test shape: {X_test.shape}")

# [8] Positional Encoding Layer (수정됨)
class PositionalEncoding(tf.keras.layers.Layer):
    def __init__(self):
        super().__init__()

    def call(self, inputs):
        seq_len = tf.shape(inputs)[1]
        d_model = inputs.shape[-1]

        pos = tf.cast(tf.range(seq_len)[:, tf.newaxis], tf.float32)
        i = tf.cast(tf.range(d_model)[tf.newaxis, :], tf.float32)

        angle_rates = 1 / tf.pow(10000.0, (2 * (i // 2)) / d_model)
        angle_rads = pos * angle_rates

        sines = tf.sin(angle_rads[:, 0::2])
        cosines = tf.cos(angle_rads[:, 1::2])
        pos_encoding = tf.concat([sines, cosines], axis=-1)

        pos_encoding = pos_encoding[tf.newaxis, ...]
        return inputs + pos_encoding

# [9] Transformer Encoder 정의
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    x = LayerNormalization(epsilon=1e-6)(inputs)
    x = MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x, x)
    x = Add()([x, inputs])

    x = LayerNormalization(epsilon=1e-6)(x)
    x_ff = Dense(ff_dim, activation='relu')(x)
    x_ff = Dense(inputs.shape[-1])(x_ff)
    return Add()([x, x_ff])

# [10] 모델 구성
input_shape = (time_steps, X_train.shape[2])
inputs = Input(shape=input_shape)
x = PositionalEncoding()(inputs)
x = transformer_encoder(x, head_size=64, num_heads=4, ff_dim=128, dropout=0.1)
x = transformer_encoder(x, head_size=64, num_heads=4, ff_dim=128, dropout=0.1)
x = GlobalAveragePooling1D()(x)
x = Dense(64, activation='relu')(x)
outputs = Dense(6)(x)

model = Model(inputs, outputs)
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.summary()

# [11] 모델 학습
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=10,
    batch_size=32
)

# [12] 학습 손실 시각화
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.title("Training and Validation Loss")
plt.show()

# [13] 예측
y_pred_scaled = model.predict(X_test)

# [14] 역정규화
y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_true = scaler_y.inverse_transform(y_test)

# [15] MAE 계산
mae_real = mean_absolute_error(y_true, y_pred)
print(f"\n실제 단위 기준 MAE: {mae_real:.4f}")

# [16] 각 항목별 MAE 출력
columns = ['x', 'y', 'z', 'yaw', 'pitch', 'roll']
mae_each = np.mean(np.abs(y_true - y_pred), axis=0)
for name, value in zip(columns, mae_each):
    print(f"{name} MAE: {value:.4f}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 데이터셋 로딩 완료
#          x         y          z     yaw   pitch    roll   q1_in   q2_in  \
# 0 -80.9148 -121.7499  1896.4867 -0.6941  0.9229 -1.4411 -2.2407 -0.7975
# 1 -80.9148 -121.7499  1896.4867 -0.6941  0.9229 -1.4411 -2.2233 -0.8511
# 2 -80.9148 -121.7499  1896.4867 -0.6941  0.9229 -1.4411 -2.2567 -0.9468
# 3 -80.9148 -121.7499  1896.4867 -0.6941  0.9229 -1.4411 -2.1557 -0.8205
# 4 -80.9148 -121.7499  1896.4867 -0.6941  0.9229 -1.4411 -2.3267 -0.9279
#
#     q3_in   q4_in   q5_in   q6_in  q1_out  q2_out  q3_out  q4_out  q5_out  \
# 0  0.6551 -3.2989  1.1212  5.7052 -2.2347 -0.8949  0.6113 -3.2841  1.2117
# 1  0.5966 -3.2320  1.1662  5.6429 -2.2347 -0.8949  0.6113 -3.2841  1.2117
# 2  0.5820 -3.3165  1.1220  5.5944 -2.2347 -0.8949  0.6113 -3.2841  1.2117
# 3  0.5532 -3.1993  1.2697  5.7474 -2.2347 -0.8949  0.6113 -3.2841  1.2117
# 4  0.6722 -3.2867  1.2266  5.6304 -2.2347 -0.8949  0.6113 -3.2841  1.2117
#
#    q6_out
# 0  5.6792
# 1  5.6792
# 2  5.6792
# 3  5.6792
# 4  5.6792
# Train shape: (239992, 10, 6), Test shape: (59998, 10, 6)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 10, 6)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ positional_encodin… │ (None, 10, 6)     │          0 │ input_layer_1[0]… │
# │ (PositionalEncodin… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 10, 6)     │         12 │ positional_encod… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 10, 6)     │      6,918 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 10, 6)     │          0 │ multi_head_atten… │
# │                     │                   │            │ positional_encod… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 10, 6)     │         12 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 10, 128)   │        896 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 10, 6)     │        774 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 10, 6)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 10, 6)     │         12 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 10, 6)     │      6,918 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 10, 6)     │          0 │ multi_head_atten… │
# │                     │                   │            │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 10, 6)     │         12 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 10, 128)   │        896 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 10, 6)     │        774 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 10, 6)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 6)         │          0 │ add_3[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 64)        │        448 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 6)         │        390 │ dense_4[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 18,062 (70.55 KB)
#  Trainable params: 18,062 (70.55 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 52s 6ms/step - loss: 0.8292 - mae: 0.7349 - val_loss: 0.7803 - val_mae: 0.7103
# Epoch 2/10
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 73s 5ms/step - loss: 0.7798 - mae: 0.7091 - val_loss: 0.7689 - val_mae: 0.7009
# Epoch 3/10
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - loss: 0.7711 - mae: 0.7044 - val_loss: 0.7639 - val_mae: 0.6996
# Epoch 4/10
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 36s 5ms/step - loss: 0.7661 - mae: 0.7010 - val_loss: 0.7592 - val_mae: 0.6972
# Epoch 5/10
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 36s 5ms/step - loss: 0.7629 - mae: 0.6991 - val_loss: 0.7633 - val_mae: 0.6997
# Epoch 6/10
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - loss: 0.7593 - mae: 0.6973 - val_loss: 0.7541 - val_mae: 0.6932
# Epoch 7/10
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 36s 5ms/step - loss: 0.7586 - mae: 0.6962 - val_loss: 0.7500 - val_mae: 0.6920
# Epoch 8/10
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 36s 5ms/step - loss: 0.7574 - mae: 0.6954 - val_loss: 0.7523 - val_mae: 0.6921
# Epoch 9/10
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - loss: 0.7547 - mae: 0.6942 - val_loss: 0.7507 - val_mae: 0.6902
# Epoch 10/10
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - loss: 0.7555 - mae: 0.6945 - val_loss: 0.7505 - val_mae: 0.6914
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
#
# 실제 단위 기준 MAE: 152.5822
# x MAE: 299.2452
# y MAE: 287.6750
# z MAE: 325.1285
# yaw MAE: 1.5723
# pitch MAE: 0.5622
# roll MAE: 1.3099

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, LayerNormalization, Dropout, GlobalAveragePooling1D
from tensorflow.keras.layers import MultiHeadAttention, Add
from tensorflow.keras.callbacks import EarlyStopping

# 데이터 로딩
csv_path = '/content/drive/MyDrive/Colab Notebooks/data/ngv/datasetIRB2400.csv'
df = pd.read_csv(csv_path)

X = df[['q1_in', 'q2_in', 'q3_in', 'q4_in', 'q5_in', 'q6_in']].values
y = df[['x', 'y', 'z', 'yaw', 'pitch', 'roll']].values

# 정규화
scaler_X = StandardScaler()
scaler_y = StandardScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# 시퀀스 생성
def create_sequences(X, y, time_steps=10):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        Xs.append(X[i:i+time_steps])
        ys.append(y[i+time_steps])
    return np.array(Xs), np.array(ys)

time_steps = 30
X_seq, y_seq = create_sequences(X_scaled, y_scaled, time_steps)
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42)

# 개선된 PositionalEncoding
class PositionalEncoding(tf.keras.layers.Layer):
    def __init__(self):
        super().__init__()

    def call(self, inputs):
        seq_len = tf.shape(inputs)[1]
        d_model = inputs.shape[-1]

        pos = tf.cast(tf.range(seq_len)[:, tf.newaxis], tf.float32)
        i = tf.cast(tf.range(d_model)[tf.newaxis, :], tf.float32)

        angle_rates = 1 / tf.pow(10000.0, (2 * (i // 2)) / d_model)
        angle_rads = pos * angle_rates

        sines = tf.sin(angle_rads[:, 0::2])
        cosines = tf.cos(angle_rads[:, 1::2])
        pos_encoding = tf.concat([sines, cosines], axis=-1)
        pos_encoding = pos_encoding[tf.newaxis, ...]
        return inputs + pos_encoding

# 개선된 Transformer encoder
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0.2):
    x = LayerNormalization(epsilon=1e-6)(inputs)
    x = MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x, x)
    x = Add()([x, inputs])

    x = LayerNormalization(epsilon=1e-6)(x)
    x_ff = Dense(ff_dim, activation='relu')(x)
    x_ff = Dropout(dropout)(x_ff)
    x_ff = Dense(inputs.shape[-1])(x_ff)
    return Add()([x, x_ff])

# 모델 구성
input_shape = (time_steps, X_train.shape[2])
inputs = Input(shape=input_shape)
x = PositionalEncoding()(inputs)
x = transformer_encoder(x, head_size=32, num_heads=8, ff_dim=256, dropout=0.2)
x = transformer_encoder(x, head_size=32, num_heads=8, ff_dim=256, dropout=0.2)
x = GlobalAveragePooling1D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)
outputs = Dense(6)(x)

model = Model(inputs, outputs)
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.summary()

# 학습
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=20,
    batch_size=64,
    callbacks=[early_stop],
    verbose=1
)

# 예측
y_pred_scaled = model.predict(X_test)
y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_true = scaler_y.inverse_transform(y_test)

# 평가 지표
mae_real = mean_absolute_error(y_true, y_pred)
rmse_real = np.sqrt(mean_squared_error(y_true, y_pred))
r2 = r2_score(y_true, y_pred)

print(f"\nMAE: {mae_real:.4f}")
print(f"RMSE: {rmse_real:.4f}")
print(f"R²: {r2:.4f}")

# 각 항목별 MAE
columns = ['x', 'y', 'z', 'yaw', 'pitch', 'roll']
mae_each = np.mean(np.abs(y_true - y_pred), axis=0)
for name, value in zip(columns, mae_each):
    print(f"{name} MAE: {value:.4f}")

# 시각화: Loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Loss Curve")
plt.grid(True)
plt.show()

# 시각화: 실제 vs 예측 (x 좌표 예시)
plt.figure()
plt.plot(y_true[:, 0], label='True x')
plt.plot(y_pred[:, 0], label='Pred x')
plt.legend()
plt.title("True vs Predicted - x")
plt.xlabel("Sample Index")
plt.ylabel("Position")
plt.grid(True)
plt.show()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 30, 6)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ positional_encodin… │ (None, 30, 6)     │          0 │ input_layer_3[0]… │
# │ (PositionalEncodin… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 30, 6)     │         12 │ positional_encod… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 30, 6)     │      6,918 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 30, 6)     │          0 │ multi_head_atten… │
# │                     │                   │            │ positional_encod… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 30, 6)     │         12 │ add_8[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 30, 256)   │      1,792 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 30, 256)   │          0 │ dense_12[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 30, 6)     │      1,542 │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 30, 6)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_13[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 30, 6)     │         12 │ add_9[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 30, 6)     │      6,918 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 30, 6)     │          0 │ multi_head_atten… │
# │                     │                   │            │ add_9[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 30, 6)     │         12 │ add_10[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 30, 256)   │      1,792 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 30, 256)   │          0 │ dense_14[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 30, 6)     │      1,542 │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 30, 6)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 6)         │          0 │ add_11[0][0]      │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 128)       │        896 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 128)       │          0 │ dense_16[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 6)         │        774 │ dropout_11[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 22,222 (86.80 KB)
#  Trainable params: 22,222 (86.80 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 43s 8ms/step - loss: 0.9088 - mae: 0.7742 - val_loss: 0.8370 - val_mae: 0.7415
# Epoch 2/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - loss: 0.8392 - mae: 0.7425 - val_loss: 0.8204 - val_mae: 0.7341
# Epoch 3/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.8266 - mae: 0.7358 - val_loss: 0.8106 - val_mae: 0.7267
# Epoch 4/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - loss: 0.8195 - mae: 0.7325 - val_loss: 0.8044 - val_mae: 0.7230
# Epoch 5/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - loss: 0.8160 - mae: 0.7302 - val_loss: 0.8024 - val_mae: 0.7240
# Epoch 6/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.8110 - mae: 0.7278 - val_loss: 0.7992 - val_mae: 0.7214
# Epoch 7/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - loss: 0.8071 - mae: 0.7258 - val_loss: 0.7971 - val_mae: 0.7207
# Epoch 8/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 40s 6ms/step - loss: 0.8060 - mae: 0.7249 - val_loss: 0.7953 - val_mae: 0.7162
# Epoch 9/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.8039 - mae: 0.7239 - val_loss: 0.7888 - val_mae: 0.7168
# Epoch 10/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.8021 - mae: 0.7229 - val_loss: 0.7937 - val_mae: 0.7174
# Epoch 11/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 39s 6ms/step - loss: 0.7992 - mae: 0.7212 - val_loss: 0.7888 - val_mae: 0.7137
# Epoch 12/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 42s 6ms/step - loss: 0.7996 - mae: 0.7214 - val_loss: 0.7846 - val_mae: 0.7140
# Epoch 13/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.7963 - mae: 0.7197 - val_loss: 0.7861 - val_mae: 0.7135
# Epoch 14/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.7963 - mae: 0.7199 - val_loss: 0.7870 - val_mae: 0.7141
# Epoch 15/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 42s 6ms/step - loss: 0.7959 - mae: 0.7196 - val_loss: 0.7873 - val_mae: 0.7148
# Epoch 16/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - loss: 0.7941 - mae: 0.7188 - val_loss: 0.7833 - val_mae: 0.7134
# Epoch 17/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 24s 7ms/step - loss: 0.7937 - mae: 0.7182 - val_loss: 0.7869 - val_mae: 0.7149
# Epoch 18/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 39s 6ms/step - loss: 0.7912 - mae: 0.7168 - val_loss: 0.7803 - val_mae: 0.7108
# Epoch 19/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.7911 - mae: 0.7167 - val_loss: 0.7845 - val_mae: 0.7126
# Epoch 20/20
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.7895 - mae: 0.7158 - val_loss: 0.7793 - val_mae: 0.7104
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
#
# MAE: 163.2516
# RMSE: 295.1743
# R²: 0.2208
# x MAE: 320.2711
# y MAE: 311.4339
# z MAE: 344.3641
# yaw MAE: 1.5710
# pitch MAE: 0.5629
# roll MAE: 1.3064
